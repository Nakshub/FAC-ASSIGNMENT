# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np

# %%
data=yf.download("AAPL",period="1y")
# Out:
# *********************100%***********************]  1 of 1 completed

# %%
plt.plot(data["Adj Close"],label="APPLE CLOSING PRICE")
plt.xlabel("DATE")
plt.ylabel("APPLE CLOSING PRICE")
plt.legend()
plt.show()
